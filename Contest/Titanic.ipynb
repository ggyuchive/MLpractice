# %% [markdown]
# <a href="https://colab.research.google.com/github/ggyuchive/MLpractice/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
# drop Passenger Id, Name
df_train.drop(df_train.columns[0], axis=1, inplace = True)
df_test.drop(df_test.columns[0], axis=1, inplace = True)
df_train.drop(df_train.columns[2], axis=1, inplace = True)
df_test.drop(df_test.columns[2], axis=1, inplace = True)
# change value
df_train = df_train.replace({'Sex':{'male':1,'female':0}})
df_train = df_train.replace({'Embarked':{'S':0,'C':1,'Q':2}})

print(df_train.shape, df_test.shape)
df_train
# Out:
# (891, 10) (418, 9)
#      Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    1  22.0      1      0         A/5 21171   7.2500
# 1           1       1    0  38.0      1      0          PC 17599  71.2833
# 2           1       3    0  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1    0  35.0      1      0            113803  53.1000
# 4           0       3    1  35.0      0      0            373450   8.0500
# ..        ...     ...  ...   ...    ...    ...               ...      ...
# 886         0       2    1  27.0      0      0            211536  13.0000
# 887         1       1    0  19.0      0      0            112053  30.0000
# 888         0       3    0   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    1  26.0      0      0            111369  30.0000
# 890         0       3    1  32.0      0      0            370376   7.7500
#
#     Cabin  Embarked
# 0     NaN       0.0
# ...

# %%
df_test
# Out:
#      Pclass                                          Name   Age  SibSp  Parch  \
# 0         3                              Kelly, Mr. James  34.5      0      0
# 1         3              Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2         2                     Myles, Mr. Thomas Francis  62.0      0      0
# 3         3                              Wirz, Mr. Albert  27.0      0      0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..      ...                                           ...   ...    ...    ...
# 413       3                            Spector, Mr. Woolf   NaN      0      0
# 414       1                  Oliva y Ocana, Dona. Fermina  39.0      0      0
# 415       3                  Saether, Mr. Simon Sivertsen  38.5      0      0
# 416       3                           Ware, Mr. Frederick   NaN      0      0
# 417       3                      Peter, Master. Michael J   NaN      1      1
#
# ...

# %%
tosub_df = pd.read_csv('gender_submission.csv')
tosub_df.to_csv('sub.csv', index=False)
